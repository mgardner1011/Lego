# %% [markdown]
# # Lego Data Exploration
# ---

# %%
# Importing libraries to use ipython-sql and sqlalchemy in this notebook
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# %sql postgresql://postgres:password@localhost/Lego_data

# %%
engine = create_engine('postgresql://postgres:password@localhost/Lego_data')

# %% [markdown]
# ### Testing that the libraries and connection to Postgresql server work

# %%
# %%sql
#
# SELECT * FROM parts
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 10 rows affected.
# [('0687b1', 'Set 0687 Activity Booklet 1', 17),
#  ('0901', 'Baseplate 16 x 30 with Set 080 Yellow House Print', 1),
#  ('0902', 'Baseplate 16 x 24 with Set 080 Small White House Print', 1),
#  ('0903', 'Baseplate 16 x 24 with Set 080 Red House Print', 1),
#  ('0904', 'Baseplate 16 x 24 with Set 080 Large White House Print', 1),
#  ('1', 'Homemaker Bookcase 2 x 4 x 4', 7),
#  ('10', 'Baseplate 24 x 32', 1),
#  ('10016414', 'Sticker Sheet #1 for 41055-1', 17),
#  ('10019stk01', 'Sticker for Set 10019 - (43274/4170393)', 17),
#  ('10026stk01', 'Sticker for Set 10026 - (44942/4184185)', 17)]

# %% [markdown]
# ### How many parts are transparent?

# %%
# %%sql
#
# SELECT * FROM colors
# WHERE is_trans = 't';
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 28 rows affected.
# [(32, 'Trans-Black IR Lens', '635F52', 't'),
#  (33, 'Trans-Dark Blue', '0020A0', 't'),
#  (34, 'Trans-Green', '84B68D', 't'),
#  (35, 'Trans-Bright Green', 'D9E4A7', 't'),
#  (36, 'Trans-Red', 'C91A09', 't'),
#  (40, 'Trans-Black', '635F52', 't'),
#  (41, 'Trans-Light Blue', 'AEEFEC', 't'),
#  (42, 'Trans-Neon Green', 'F8F184', 't'),
#  (43, 'Trans-Very Lt Blue', 'C1DFF0', 't'),
#  (45, 'Trans-Dark Pink', 'DF6695', 't'),
#  (46, 'Trans-Yellow', 'F5CD2F', 't'),
#  (47, 'Trans-Clear', 'FCFCFC', 't'),
#  (52, 'Trans-Purple', 'A5A5CB', 't'),
#  (54, 'Trans-Neon Yellow', 'DAB000', 't'),
#  (57, 'Trans-Neon Orange', 'FF800D', 't'),
#  (114, 'Glitter Trans-Dark Pink', 'DF6695', 't'),
#  (117, 'Glitter Trans-Clear', 'FFFFFF', 't'),
#  (129, 'Glitter Trans-Purple', 'A5A5CB', 't'),
#  (143, 'Trans-Medium Blue', 'CFE2F7', 't'),
#  (182, 'Trans-Orange', 'F08F1C', 't'),
#  (230, 'Trans-Pink', 'E4ADC8', 't'),
#  (236, 'Trans-Light Purple', '96709F', 't'),
#  (294, 'Glow In Dark Trans', 'BDC6AD', 't'),
#  (1002, 'Glitter Trans-Neon Green', 'C0F500', 't'),
#  (1003, 'Glitter Trans-Light Blue', '68BCC5', 't'),
#  (1004, 'Trans Flame Yellowish Orange', 'FCB76D', 't'),
#  (1005, 'Trans Fire Yellow', 'FBE890', 't'),
#  (1006, 'Trans Light Royal Blue', 'B4D4F7', 't')]

# %% [markdown]
# ### How many sets have a transparent piece in them?

# %%
# %%sql
#
# SELECT COUNT(*) FROM sets as s
# JOIN inventories as i
# ON s.set_num = i.set_num
# JOIN inventory_parts as ip
# ON i.id = ip.inventory_id
# JOIN colors as c
# ON ip.color_id = c.id
# WHERE c.is_trans = 't';
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(36318,)]

# %% [markdown]
# ### Which parts are there the least of in a set?

# %%
# %%sql
#
# SELECT p.name, s.num_parts
# FROM parts as p
# JOIN inventory_parts as ip
# ON p.part_num = ip.part_num
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# WHERE s.num_parts < 2;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 274 rows affected.
# [('Train Base 6 x 22 with Magnets', 1),
#  ('Electric Mindstorms NXT Temperature Sensor', 1),
#  ('Electric 9V Battery Box Small [Complete Assembly]', 1),
#  ('Brick Separator v1.0', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Electric, Sound Siren 9V 2 x 2 x 1 1/3 with Two Space Noises', 1),
#  ('Electric Motor 4.5V/12V Type II 12 x 4 x 3 1/3 Gearbox (Train)', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Pneumatic Cylinder with 1 Inlet Large (64mm)', 1),
#  ('Lord Vladek Sword', 1),
#  ('9V Battery Box 4 x 14 x 4 with Dark Gray Base Complete Assembly', 1),
#  ('Electric, Train 12V Flash Light Unit 4 x 4 x 1 2/3', 1),
#  ('Scala Baseplate 44 x 22 with 4 holes', 1),
#  ('LPF2.0 MEDIUM MOTOR', 1),
#  ('Hose, Pneumatic 4mm D.', 1),
#  ('Electric Motor 9V 5 x 4 x 2 1/3', 1),
#  ('Electric, Train Track Contact Base with Wire (97 cm) and Connector, Complete Assembly', 1),
#  ('Boat Keel Weighted 8 x 2 x 4', 1),
#  ('~Electric Train Motor 12V Slotted with 3-Hole Plugs', 1),
#  ('Ring 4 x 4 with 2 x 2 Hole and 4 Snake Head Ends and Gold Scales Snake Print (Ninjago Spinner Crown)', 1),
#  ('9V Battery Box 4 x 14 x 4 with Dark Gray Base Complete Assembly', 1),
#  ('Pneumatic Cylinder with 1 Inlet Medium (48mm)', 1),
#  ('Electric Train Motor 4.5V Replacement', 1),
#  ('Electric Motor Medium - EV3', 1),
#  ('Max, Red Torso, Black Legs', 1),
#  ('Container Storage Folder with 16 Size A4 Transparent Pockets', 1),
#  ('Baseplate 48 x 48', 1),
#  ('Storage Bin with Retractable Handle on Top - LEGO System Print', 1),
#  ('Monorail Motor 9V with Short Couplings (Complete Assembly)', 1),
#  ('Pneumatic Pump Old Style', 1),
#  ('Baseplate 16 x 32', 1),
#  ('Train, Track 9V Crossing', 1),
#  ('Idea Book 8890, Technic', 1),
#  ('Minifig (Unknown)', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Throwing Disk (generic catalog entry)', 1),
#  ('Duplo Car with 2 x 2 Studs and Yellow Base', 1),
#  ('Electric Power Functions LED Light Unit with Black PF Connector Lead', 1),
#  ('Electric, Train 12V Remote Control 8 x 10 with Level Crossing Print', 1),
#  ('Batman (Comic-Con 2011 Exclusive)', 1),
#  ('Pneumatic Cylinder with 1 Inlet Medium (48mm)', 1),
#  ('Electric 4.5V Battery Box 6 x 11 x 3 1/3 Type 3 [Complete]', 1),
#  ('Electric Compass Sensor - NXT', 1),
#  ('Wire with Brick 2 x 2 x 2/3 Pair, 162 Studs Long', 1),
#  ('Electric, Train 12V Transformer for 220V', 1),
#  ('Brick Separator v1.0', 1),
#  ('Electric 7.4V Rechargeable Battery - NXT, AC plug', 1),
#  ('Electric 9V Battery Box 4 x 14 x 4 with Yellow Base Complete Assembly', 1),
#  ('Electric Train 12V Manual Switch Motor 4 x 8 x 1 2/3', 1),
#  ('LPF2 SMART HUB 2 I/O 4X8X3', 1),
#  ('Tina, Red Torso and Red Legs', 1),
#  ('Electric Compass Sensor - NXT', 1),
#  ('Technic Gearbox 2 x 4 x 3 1/3', 1),
#  ('Electric, Sensor, Infrared Seeker, Version 2', 1),
#  ('Brick 2 x 4', 1),
#  ('Electric Battery Box 9V 150mAh (Rechargeable) for Energy Display', 1),
#  ('Brick 2 x 4', 1),
#  ('Baseplate 48 x 48', 1),
#  ('Town Plan Board, Cardboard European Left-Driving (50 1/2cm x 79 1/2cm) - Set 200-5', 1),
#  ('Storage Cabinet with Slots for 4 Trays', 1),
#  ('Rechargeable DC Battery - EV3', 1),
#  ('Electric Wire with Brick 2 x 2 x 2/3 Pair, 15 Studs Long', 1),
#  ('Idea Book 8888, Technic', 1),
#  ('Minifig Star Wars Blaster Short', 1),
#  ('Electric Light Brick 4.5V 2 x 4 Replacement Bulb', 1),
#  ('Storage Cloth [Blue Denim, Red Drawstrring]', 1),
#  ('Electric Power Functions Pole Reverser / Polarity Switch with Black Lead', 1),
#  ('Electric Light Sensor with Non-Removable Lead', 1),
#  ('Electric Mindstorms EV3 Infrared Sensor', 1),
#  ('Electric Mindstorms EV3 IR-Beacon / Remote Handset', 1),
#  ('Electric 4.5V Battery Box 6 x 11 x 3 1/3 Type 3 [Complete]', 1),
#  ('Pneumatic Pump New Style with Black Top', 1),
#  ('SmartHub rechargeable battery', 1),
#  ('Electric, Train Speed Regulator 9V Power Adaptor 240V (UK)', 1),
#  ('Town Plan Board, Masonite (53 1/2cm x 80cm) - Sets 200A, 1200A, 200M', 1),
#  ('Pneumatic Cylinder 1 x 5 with 2 Inlets', 1),
#  ('Storage/Sorting Tray - Twenty Four Compartment', 1),
#  ('Tote Bag, Lego Logo Print, Red Handles and Bottom', 1),
#  ('Brick Special 2 x 2 Racer Driver Round Head (Undetermined Print)', 1),
#  ('Electric Motor 4.5V Type II 12 x 4 x 3 1/3 Lower Housing (Train)', 1),
#  ('Friends Handbag with Zipper and Dark Purple Side Print', 1),
#  ('Baseplate 16 x 32', 1),
#  ('Storage Cloth [Blue Denim, Red Drawstrring]', 1),
#  ('Null Set Place Holder', 1),
#  ('Colour Sensor - EV3', 1),
#  ('Storage Box Plaid with White Handle and Metal Corner Protectors', 1),
#  ('Electric Motor - NXT', 1),
#  ('Electric Motor 12V Type 1 for 2-Prong Connectors with Middle Pin', 1),
#  ('Electric Sound Sensor - NXT', 1),
#  ('Town Plan Board, Masonite (53 1/2cm x 80cm) - Sets 200A, 1200A, 200M', 1),
#  ('Solar Panel with Light Bluish Gray Top', 1),
#  ('Storage Case with Molded Internal Tray with Four Compartments', 1),
#  ('Electric Lightbrick 2 x 2 Type 1 - 4.5V [Complete]', 1),
#  ('Electric Power Functions IR Speed Remote Control with Dark Bluish Gray Bottom', 1),
#  ('Electric Touch Sensor - Fixed Lead', 1),
#  ('Mindstorms EV3 - Complete Brick', 1),
#  ('Electric 9V Battery Box Small [Complete Assembly]', 1),
#  ('Touch Sensor - EV3', 1),
#  ('Technic Propeller 3 Blade with 24t Gear [8855 / 5113]', 1),
#  ('Electric, Sensor, Tilt - WeDo Robotics', 1),
#  ('Electric Rotation Sensor', 1),
#  ('Electric Temperature Sensor - Short Lead', 1),
#  ('Electric, Train Track Contact Base with Wire (97 cm) and Connector with Cap, Complete Assembly', 1),
#  ('Electric Power Functions Battery Box with Dark Bluish Gray Bottom [Non-Rechargeable]', 1),
#  ('Electric Train Motor 4.5V Replacement', 1),
#  ('Electric Colour Sensor - NXT2', 1),
#  ('Baseplate 50 x 50', 1),
#  ('Minifig Head Alien with Spider-Man Black Web Print [Hollow Stud]', 1),
#  ('Electric Motor 9V 5 x 4 x 2 1/3', 1),
#  ('Tina, Red Torso and Red Legs', 1),
#  ('Electric Touch Sensor 4.5V', 1),
#  ('Pneumatic Pump Old Style', 1),
#  ('Idea Book 250 [1987]', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Idea Book 8889, Technic', 1),
#  ('Wire with Brick 2 x 2 x 2/3 Pair, 36 Studs Long', 1),
#  ('Electric Lightbrick  2 x  2 Type 2 12V with Red Diffusor', 1),
#  ('Electric 4.5V Battery Box 6 x 11 x 3 1/3 Type 3 [Complete]', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Town Plan Board, Plastic Small Soft [200-3 / 1200-2]', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Electric Mindstorms EV3 Ultrasonic Sensor', 1),
#  ('Electric, Hub, USB - WeDo Robotics', 1),
#  ('Electric Temperature Sensor - Short Lead', 1),
#  ('Electric, Train Track Contacts with Wire and 2 x 2 x 2/3 Brick', 1),
#  ('The LEGO Ideas Book - Unlock Your Imagination', 1),
#  ('Electric Power Functions E-Motor (Complete)', 1),
#  ('Storage Cloth [Blue Denim, Red Drawstrring]', 1),
#  ('Mindstorms NXT - Complete Brick with Dark Bluish Gray Base', 1),
#  ('Minifig Sword Blocky (Minecraft Sword)', 1),
#  ('Electric 9V Mini-Motor [Lightweight New Style]', 1),
#  ('Interface Card/Cable for TC Logo Kit', 1),
#  ('Pneumatic Cylinder with 1 Inlet Large (64mm)', 1),
#  ('Electric Train Motor 12V Replacement', 1),
#  ('Mindstorms RCX 1.0 with Power Jack - Complete Brick', 1),
#  ('Technic Figure Cyber Person, Black Legs, Mechanical Arms, Yellow Head, Cyborg Eyepiece', 1),
#  ('Brick 2 x 4', 1),
#  ('Lord Vladek Mask', 1),
#  ('Road Safety Booklet [K1062]', 1),
#  ('Train Base 6 x 28  with Two 1 x 2 Cutouts [3 Round Holes Each End]', 1),
#  ('Electric Motor with Boat Propeller and Rudder - Complete Assembly 14 x 4 x 4, 4-Blade Propeller', 1),
#  ('Electric Adapter / Transformer, 120V / 10V DC', 1),
#  ('DK Brickmaster Star Wars - Battle for the Stolen Crystals - Hardcover Book ONLY', 1),
#  ('Sensor, Infrared (IR) Link - NXT', 1),
#  ('Shazam (Comic-Con 2012 Exclusive)', 1),
#  ('Minifig Jack - Complete Assembly', 1),
#  ('Storage Case with Molded Internal Tray with Four Compartments', 1),
#  ('Electric Motor 4.5V Type II 12 x 4 x 3 1/3 Lower Housing (Train)', 1),
#  ('LPF2 SENSOR TILT 2X4X1', 1),
#  ('Friends Tumbler with Straw', 1),
#  ('Minifig Hair Mid-Length Tousled with Center Part', 1),
#  ('Brick and Axle Separator v2.0', 1),
#  ('Wire with Brick 2 x 2 x 2/3 Pair, 162 Studs Long', 1),
#  ('Town Plan Board, Plastic Small Soft [200-3 / 1200-2]', 1),
#  ('Minifig Batarang', 1),
#  ('Train Base 6 x 28  with Two 1 x 2 Cutouts [3 Round Holes Each End]', 1),
#  ('Electric Train Motor 4.5V Replacement', 1),
#  ('Paper, Cardboard Base for Sets 359 and 355', 1),
#  ('Electric Power Functions Medium Motor 3 x 6 x 3 with Dark Bluish Gray Bottom and 20cm Wire', 1),
#  ('Electric, Train 12V Transformer for 110V', 1),
#  ('Electric Motor 4.5V Type 2 for 2-Prong Connectors with Middle Pin', 1),
#  ('Brick 1 x 2 without Bottom Tube, Slotted (with 1 slot)', 1),
#  ('Electric Touch Sensor - NXT', 1),
#  ('Train Base 6 x 28 with Two 1 x 2 Cutouts [10 Round Holes Each End and 1 Round Hole at Center]', 1),
#  ('Ultimate Sticker Collection - Minifigure', 1),
#  ('Town Plan Board, Plastic Large Soft [1200]', 1),
#  ('Train Base 6 x 22 with Magnets', 1),
#  ('Electric Train Motor 4.5V Replacement', 1),
#  ('Electric, Sensor, Motion - WeDo Robotics', 1),
#  ('Wooden Storage Box with Red Sliding Top', 1),
#  ('Electric Power Functions Servo Motor with Dark Bluish Gray Bottom', 1),
#  ('Electric, Sound Siren 9V 2 x 2 x 1 1/3 with Two Space Noises', 1),
#  ('Technic Storage Case 36 x 48 with Removable Tray and Dividers', 1),
#  ('Electric Light Sensor - NXT', 1),
#  ('Dacta Storage Bin Lid [For New Style Trays]', 1),
#  ('Electric Motor 4.5V/12V Type II 12 x 4 x 3 1/3 Gearbox (Train)', 1),
#  ('Electric Power Functions XL Motor 6 x 6 x 6 with Dark Bluish Gray Bottom and 20cm Wire', 1),
#  ('Electric 4.5V Battery Box 6 x 11 x 3 1/3 Type 3 [Complete]', 1),
#  ('Storage Bin with Retractable Handle on Top - LEGO System Print', 1),
#  ('Electric Magnetic Sensor - NXT', 1),
#  ('Electric Ultrasonic Sensor - NXT', 1),
#  ('Electric Power Functions Extension Wire with one Light Bluish Gray End [50cm]', 1),
#  ('Electric Train Motor 12V Replacement', 1),
#  ('Dacta Storage Bin Lid [For New Style Trays]', 1),
#  ('String, Elastic', 1),
#  ('Electric, Adapter / Transformer, 120V - 10V AC', 1),
#  ('Batman (Comic-Con 2011 Exclusive)', 1),
#  ('Electric Power Functions Large Motor with Dark Bluish Gray Bottom', 1),
#  ('Storage Bin with Retractable Handle on Top - LEGO System Print', 1),
#  ('Minifig Jack - Complete Assembly', 1),
#  ('Electric 7.4V Rechargeable Battery - NXT [DC plug]', 1),
#  ('Electric Power Functions Battery Box 4 x 11 x 7 with Orange Switch and Dark Bluish Gray Covers', 1),
#  ('Electric Mindstorms EV3 Large Motor', 1),
#  ('Electric Power Functions IR Remote Control with Dark Bluish Gray Bottom', 1),
#  ('Electric Sound Siren 9V 2 x 2 x 1 1/3 with Two Town Police Noises', 1),
#  ('Brick Separator v1.0', 1),
#  ('Max, Red Torso, Black Legs', 1),
#  ('Electric Motor 4.5V Type II 12 x 4 x 3 1/3 Upper Housing (Train)', 1),
#  ('Baseplate 48 x 48', 1),
#  ('Train, Track 12V Conducting Rail Straight for 12v Signal with Rail Interruption at End', 1),
#  ('Wooden Storage Box with Plain Sliding Top and LEGO Logo', 1),
#  ('Scala Baseplate 44 x 44 with 4 holes', 1),
#  ('Train Track 12V Conducting Rail Curved with Connection Wire', 1),
#  ('Electric Power Functions Extension Wire with One Light Bluish Gray End [20cm]', 1),
#  ('Torso Black Striped Vest with Clasps and Lime Lines, Zipper, Belt with Gold Buckle and Muscles Print (Green Arrow) / Light Flesh Arms / Green Hands', 1),
#  ('Electric Motor 4.5V Type 2 for 2-Prong Connectors with Middle Pin', 1),
#  ('Sound Siren 9V 2 x 2 x 1 1/3 [Undetermined Noise Type]', 1),
#  ('Electric 4.5V Battery Box 6 x 11 x 3 1/3 Type 3 [Complete]', 1),
#  ('Electric Technic Capacitor with Clear Top', 1),
#  ('Friends Dog Small Standing with Blue Eyes, Black Nose and Mouth Print', 1),
#  ('Baseplate 48 x 48', 1),
#  ('Train Base 6 x 28 with Two 1 x 2 Cutouts [10 Round Holes Each End and 1 Round Hole at Center]', 1),
#  ('Duplo Baseplate 24 x 24', 1),
#  ('Electric, Motor 4.5V Type III 12 x 4 x 3 1/3 (open contacts)', 1),
#  ('Mindstorms NXT - Complete Brick with Dark Bluish Gray Base', 1),
#  ('Electric 4.5V Battery Box 7 x 11 x 3 Type 2 [Complete]', 1),
#  ('Brick 2 x 4', 1),
#  ('Electric 4.5V 3 C-Cell Battery Box with Switch 4 x 24 Complete Assembly', 1),
#  ('Electric Light Sensor with Non-Removable Lead', 1),
#  ('Electric Solar Cell', 1),
#  ('Storage Box Plaid with Red Handle', 1),
#  ('Minifig Spear Gun', 1),
#  ("Minifig Visor - Diver's Mask", 1),
#  ('Brick 2 x 4', 1),
#  ('Storage Case with Two Latches 30 x 42 x 11 studs', 1),
#  ('Pneumatic Switch with Top Studs', 1),
#  ('Primo Teether Star with 8 Arms, Yellow Center and Face Print', 1),
#  ('Brick 2 x 4', 1),
#  ('Gyro Sensor - EV3', 1),
#  ('Electric Rotation Sensor', 1),
#  ('Electric, Train Speed Regulator 9V Power Adaptor 230V (Continental European type)', 1),
#  ('CD-Rom for Robotics Invention System Upgrade Kit (2.0)', 1),
#  ('Electric Motor 4.5V Type 1 for 2-Prong Connectors without Middle Pin', 1),
#  ('Book - Standing Small: A Celebration of 30 years of the Lego Minifigure', 1),
#  ('Electric 4.5V 3 C-Cell Battery Box with Switch 4 x 24 Complete Assembly', 1),
#  ('Electric, Train Track Contacts with Wire and 2 x 2 x 2/3 Brick', 1),
#  ('Storage Bin with Retractable Handle on Top - LEGO System Print', 1),
#  ('Energy Unit with Display 6 x 8 x 3 1/3', 1),
#  ('Electric Switch: Remote Control for Train Point', 1),
#  ('Town Plan Board, Cardboard European Right-Driving (50 1/2cm x 79 1/2cm) - Set 200-4', 1),
#  ('Minifig Star Wars Blaster Short', 1),
#  ('Storage/Sorting Tray - Ten Compartment', 1),
#  ('Electric 4.5V Battery Box 7 x 11 x 3 Type 1 (Complete)', 1),
#  ('Electric Motor 4.5V Type 1 for 2-Prong Connectors without Middle Pin', 1),
#  ('Wire with Brick 2 x 2 x 2/3 Pair, 36 Studs Long', 1),
#  ('Blacktron Super Model Instructions', 1),
#  ('Scala Baseplate 44 x 22 x 1/3 without holes', 1),
#  ('Transformer', 1),
#  ('Train 12V Transformer for 220V Type 2', 1),
#  ('Electric Pole Reverser / Polarity Switch with Center Part [Complete Assembly]', 1),
#  ('Mindstorms RCX Remote Control', 1),
#  ('Storage Cloth [Blue Denim, Red Drawstrring]', 1),
#  ('Electric Power Functions Battery Box with Dark Bluish Gray Bottom [Rechargeable]', 1),
#  ('Brick 2 x 4', 1),
#  ('Electric 4.5V 3 C-Cell Battery Box with Switch 4 x 24 Complete Assembly', 1),
#  ('Bionicle Mask, Kanohi Hau (Mask of Fire)', 1),
#  ('Town Plan Board, Masonite (53 1/2cm x 80cm) - Sets 200A, 1200A, 200M', 1),
#  ('The LEGO Ideas Book - You Can Build Anything!', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Idea Book 8891, Technic', 1),
#  ('Pneumatic Cylinder with 2 Inlets Medium (48mm) with Black Top', 1),
#  ('Electric Power Functions IR Receiver', 1),
#  ('Electric, Sensor, Color - NXT', 1),
#  ('Electric Motor 4.5V/12V Type II 12 x 4 x 3 1/3 Gearbox (Train)', 1),
#  ('Electric Motor 9V 4 x 10 x 3', 1),
#  ('Baseplate 32 x 32', 1),
#  ('Baseplate 32 x 32', 1),
#  ('LPF2 SENSOR DETECT 2X4X1', 1),
#  ('Storage Box Plaid with White Handle and Metal Corner Protectors', 1),
#  ('Sound Siren 9V 2 x 2 x 1 1/3 [Undetermined Noise Type]', 1),
#  ('Tile Special 6 x 4 with Beveled Edges and 7mm Pin (Train Bogie Plate)', 1),
#  ('Baseplate 48 x 48', 1),
#  ('Electric, Train 12V Remote Control 8 x 10 with Signal Print', 1),
#  ('Brick 2 x 4', 1)]

# %% [markdown]
# ### What are the different years in the dataset?

# %%
# %%sql
#
# SELECT DISTINCT(year) FROM sets
# ORDER BY year;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 66 rows affected.
# [(1950,),
#  (1953,),
#  (1954,),
#  (1955,),
#  (1956,),
#  (1957,),
#  (1958,),
#  (1959,),
#  (1960,),
#  (1961,),
#  (1962,),
#  (1963,),
#  (1964,),
#  (1965,),
#  (1966,),
#  (1967,),
#  (1968,),
#  (1969,),
#  (1970,),
#  (1971,),
#  (1972,),
#  (1973,),
#  (1974,),
#  (1975,),
#  (1976,),
#  (1977,),
#  (1978,),
#  (1979,),
#  (1980,),
#  (1981,),
#  (1982,),
#  (1983,),
#  (1984,),
#  (1985,),
#  (1986,),
#  (1987,),
#  (1988,),
#  (1989,),
#  (1990,),
#  (1991,),
#  (1992,),
#  (1993,),
#  (1994,),
#  (1995,),
#  (1996,),
#  (1997,),
#  (1998,),
#  (1999,),
#  (2000,),
#  (2001,),
#  (2002,),
#  (2003,),
#  (2004,),
#  (2005,),
#  (2006,),
#  (2007,),
#  (2008,),
#  (2009,),
#  (2010,),
#  (2011,),
#  (2012,),
#  (2013,),
#  (2014,),
#  (2015,),
#  (2016,),
#  (2017,)]

# %% [markdown]
# ### The next few blocks are seeing how the number of colors in sets changed over the years

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(c.name))
# FROM colors as c
# JOIN inventorY_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# WHERE s.year BETWEEN 1950 AND 1957;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(15,)]

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(c.name))
# FROM colors as c
# JOIN inventorY_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# WHERE s.year BETWEEN 1958 AND 1963;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(12,)]

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(c.name))
# FROM colors as c
# JOIN inventorY_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# WHERE s.year BETWEEN 1964 AND 1969;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(14,)]

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(c.name))
# FROM colors as c
# JOIN inventorY_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# WHERE s.year BETWEEN 2011 AND 2017;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(92,)]

# %% [markdown]
# ### Which theme has the most colors in it?

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(c.name)) as color_count, t.name as theme_name
# FROM colors as c
# JOIN inventory_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# JOIN themes as t
# ON s.theme_id = t.id
# GROUP BY t.name
# ORDER BY COUNT(DISTINCT(c.name)) DESC
# LIMIT 25;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 25 rows affected.
# [(77, 'Basic Set'),
#  (75, 'Fairy-Tale'),
#  (66, 'Duplo'),
#  (64, 'Star Wars'),
#  (64, 'Playhouse'),
#  (64, 'Creator'),
#  (63, 'Friends'),
#  (63, 'Ninjago'),
#  (63, 'Batman'),
#  (62, 'Star Wars Episode 4/5/6'),
#  (62, 'Supplemental'),
#  (58, 'Harry Potter'),
#  (58, 'Elves'),
#  (58, 'Christmas'),
#  (58, 'Town'),
#  (58, 'Disney Princess'),
#  (56, 'Modular Buildings'),
#  (56, 'Other'),
#  (56, 'Spider-Man'),
#  (56, 'Gear'),
#  (55, 'Juniors'),
#  (55, 'LEGO Ideas and CUUSOO'),
#  (54, 'LEGO Brand Store'),
#  (54, 'Super Heroes'),
#  (54, 'Construction')]

# %% [markdown]
# ### What are the colors in the theme with the most colors?

# %%
# %%sql
#
# SELECT DISTINCT(c.name)
# FROM colors as c
# JOIN inventory_parts as ip
# ON c.id = ip.color_id
# JOIN inventories as i
# ON ip.inventory_id = i.id
# JOIN sets as s
# ON i.set_num = s.set_num
# JOIN themes as t
# ON s.theme_id = t.id
# WHERE t.name = 'Basic Set';
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 77 rows affected.
# [('Aqua',),
#  ('Dark Blue',),
#  ('Red',),
#  ('Bright Green',),
#  ('Trans-Dark Blue',),
#  ('Medium Azure',),
#  ('Lavender',),
#  ('Trans-Red',),
#  ('Light Yellow',),
#  ('Sand Red',),
#  ('Earth Orange',),
#  ('Purple',),
#  ('Dark Purple',),
#  ('[No Color]',),
#  ('Bright Light Blue',),
#  ('Yellow',),
#  ('Dark Gray',),
#  ('Medium Blue',),
#  ('Medium Orange',),
#  ('Black',),
#  ('Flesh',),
#  ('Sand Green',),
#  ('Trans-Bright Green',),
#  ('Orange',),
#  ('Yellowish Green',),
#  ('Pearl Light Gray',),
#  ('Dark Tan',),
#  ('Dark Orange',),
#  ('Trans-Yellow',),
#  ('Medium Lavender',),
#  ('Medium Lime',),
#  ('Dark Brown',),
#  ('Tan',),
#  ('Trans-Medium Blue',),
#  ('Metallic Silver',),
#  ('Bright Pink',),
#  ('Trans-Purple',),
#  ('Lime',),
#  ('Magenta',),
#  ('Milky White',),
#  ('Pearl Gold',),
#  ('Dark Green',),
#  ('Chrome Gold',),
#  ('Pink',),
#  ('Blue',),
#  ('Trans-Neon Orange',),
#  ('Trans-Orange',),
#  ('Trans-Clear',),
#  ('Sand Blue',),
#  ('Trans-Neon Green',),
#  ('Dark Bluish Gray',),
#  ('Light Bluish Gray',),
#  ('Bright Light Orange',),
#  ('Medium Dark Flesh',),
#  ('Medium Green',),
#  ('Dark Pink',),
#  ('Trans-Light Blue',),
#  ('Light Gray',),
#  ('Chrome Silver',),
#  ('Bright Light Yellow',),
#  ('Royal Blue',),
#  ('Green',),
#  ('Light Aqua',),
#  ('Trans-Green',),
#  ('Dark Turquoise',),
#  ('Reddish Brown',),
#  ('White',),
#  ('Light Purple',),
#  ('Very Light Gray',),
#  ('Trans-Black',),
#  ('Light Blue',),
#  ('Dark Azure',),
#  ('Dark Red',),
#  ('Flat Silver',),
#  ('Metallic Gold',),
#  ('Brown',),
#  ('Trans-Dark Pink',)]

# %% [markdown]
# ### How many sets were released each year?

# %%
# %%sql
#
# SELECT COUNT(name), year
# FROM sets
# GROUP BY year
# ORDER BY year;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 66 rows affected.
# [(7, 1950),
#  (4, 1953),
#  (14, 1954),
#  (28, 1955),
#  (12, 1956),
#  (21, 1957),
#  (42, 1958),
#  (4, 1959),
#  (3, 1960),
#  (17, 1961),
#  (40, 1962),
#  (18, 1963),
#  (11, 1964),
#  (10, 1965),
#  (89, 1966),
#  (21, 1967),
#  (25, 1968),
#  (69, 1969),
#  (29, 1970),
#  (45, 1971),
#  (38, 1972),
#  (67, 1973),
#  (39, 1974),
#  (31, 1975),
#  (68, 1976),
#  (92, 1977),
#  (73, 1978),
#  (82, 1979),
#  (88, 1980),
#  (79, 1981),
#  (76, 1982),
#  (57, 1983),
#  (76, 1984),
#  (139, 1985),
#  (123, 1986),
#  (209, 1987),
#  (68, 1988),
#  (115, 1989),
#  (85, 1990),
#  (107, 1991),
#  (115, 1992),
#  (111, 1993),
#  (128, 1994),
#  (128, 1995),
#  (144, 1996),
#  (192, 1997),
#  (325, 1998),
#  (300, 1999),
#  (327, 2000),
#  (339, 2001),
#  (447, 2002),
#  (415, 2003),
#  (371, 2004),
#  (330, 2005),
#  (283, 2006),
#  (321, 2007),
#  (349, 2008),
#  (402, 2009),
#  (444, 2010),
#  (503, 2011),
#  (615, 2012),
#  (593, 2013),
#  (713, 2014),
#  (665, 2015),
#  (596, 2016),
#  (296, 2017)]

# %% [markdown]
# ### How many sets have a spare part?

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM sets as s
# JOIN inventories as i
# ON s.set_num = i.set_num
# JOIN inventory_parts as ip
# ON i.id = ip.inventory_id
# WHERE ip.is_spare = 't';
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 1 rows affected.
# [(29495,)]

# %% [markdown]
# ### Which themes have the largest number of sets in them?

# %%
# %%sql
#
# SELECT COUNT(DISTINCT(s.name)), t.name
# FROM sets as s
# JOIN themes as t
# ON s.theme_id = t.id
# GROUP BY t.name
# ORDER BY COUNT(DISTINCT(s.name)) DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/Lego_data
# 10 rows affected.
# [(421, 'Supplemental'),
#  (409, 'Technic'),
#  (285, 'City'),
#  (268, 'Friends'),
#  (242, 'Creator'),
#  (238, 'Gear'),
#  (213, 'Service Packs'),
#  (211, 'Duplo'),
#  (207, 'Star Wars'),
#  (186, 'Ninjago')]
